# %%
import pandas as pd
st=pd.read_excel("/content/Data (2).xlsx")
print(st)
# Out:
#     Student_ID Student_Name  Gender  Age       City      State Department  \
# 0         S001      Anita_1    Male   19   Belagavi  Karnataka        MBA
# 1         S002     Suresh_2    Male   24  Bengaluru  Karnataka        BCA
# 2         S003     Suresh_3    Male   21   Hubballi  Karnataka        MBA
# 3         S004       Asha_4  Female   25   Belagavi  Karnataka        MBA
# 4         S005      Deepa_5  Female   25  Bengaluru  Karnataka        MCA
# ..         ...          ...     ...  ...        ...        ...        ...
# 500       S011     Rahul_11    Male   23     Mysuru  Karnataka        MBA
# 501       S087     Rohan_87  Female   18  Bengaluru  Karnataka        MCA
# 502       S154   Vikram_154  Female   19  Mangaluru  Karnataka       BCom
# 503       S259     Neha_259  Female   18   Hubballi  Karnataka        BCA
# 504       S332    Deepa_332    Male   19    Dharwad  Karnataka        MBA
#
#      Semester  Admission_Year  Study_Hours  ...  Projects_Completed  \
# ...

# %%
st.head()
# Out:
#   Student_ID Student_Name  Gender  Age       City      State Department  \
# 0       S001      Anita_1    Male   19   Belagavi  Karnataka        MBA
# 1       S002     Suresh_2    Male   24  Bengaluru  Karnataka        BCA
# 2       S003     Suresh_3    Male   21   Hubballi  Karnataka        MBA
# 3       S004       Asha_4  Female   25   Belagavi  Karnataka        MBA
# 4       S005      Deepa_5  Female   25  Bengaluru  Karnataka        MCA
#
#    Semester  Admission_Year  Study_Hours  ...  Projects_Completed  Internship  \
# 0         1            2023            1  ...                   3          No
# 1         1            2023            5  ...                   1         Yes
# 2         4            2024            8  ...                   3          No
# 3         1            2022            9  ...                   1          No
# 4         3            2025            2  ...                   5          No
#
# ...

# %%
st.head(20)
# Out:
#    Student_ID Student_Name  Gender  Age       City      State Department  \
# 0        S001      Anita_1    Male   19   Belagavi  Karnataka        MBA
# 1        S002     Suresh_2    Male   24  Bengaluru  Karnataka        BCA
# 2        S003     Suresh_3    Male   21   Hubballi  Karnataka        MBA
# 3        S004       Asha_4  Female   25   Belagavi  Karnataka        MBA
# 4        S005      Deepa_5  Female   25  Bengaluru  Karnataka        MCA
# 5        S006      Pooja_6    Male   25  Bengaluru  Karnataka        BCA
# 6        S007      Arjun_7  Female   23  Mangaluru  Karnataka       BCom
# 7        S008      Kavya_8  Female   23     Mysuru  Karnataka        MBA
# 8        S009     Nikhil_9    Male   19   Belagavi  Karnataka        MBA
# 9        S010     Meena_10  Female   25  Bengaluru  Karnataka        MCA
# 10       S011     Rahul_11    Male   23     Mysuru  Karnataka        MBA
# 11       S012     Rohan_12    Male   21    Dharwad  Karnataka       BCom
# ...

# %%
st.tail()
# Out:
#     Student_ID Student_Name  Gender  Age       City      State Department  \
# 500       S011     Rahul_11    Male   23     Mysuru  Karnataka        MBA
# 501       S087     Rohan_87  Female   18  Bengaluru  Karnataka        MCA
# 502       S154   Vikram_154  Female   19  Mangaluru  Karnataka       BCom
# 503       S259     Neha_259  Female   18   Hubballi  Karnataka        BCA
# 504       S332    Deepa_332    Male   19    Dharwad  Karnataka        MBA
#
#      Semester  Admission_Year  Study_Hours  ...  Projects_Completed  \
# 500         1            2024            2  ...                   2
# 501         4            2025            6  ...                   2
# 502         4            2025            4  ...                   2
# 503         3            2025            1  ...                   2
# 504         4            2022            6  ...                   4
#
#      Internship  Scholarship  Placement_Status   Exam_Date  Total_Marks  \
# ...

# %%
st.tail(5)
# Out:
#     Student_ID Student_Name  Gender  Age       City      State Department  \
# 500       S011     Rahul_11    Male   23     Mysuru  Karnataka        MBA
# 501       S087     Rohan_87  Female   18  Bengaluru  Karnataka        MCA
# 502       S154   Vikram_154  Female   19  Mangaluru  Karnataka       BCom
# 503       S259     Neha_259  Female   18   Hubballi  Karnataka        BCA
# 504       S332    Deepa_332    Male   19    Dharwad  Karnataka        MBA
#
#      Semester  Admission_Year  Study_Hours  ...  Projects_Completed  \
# 500         1            2024            2  ...                   2
# 501         4            2025            6  ...                   2
# 502         4            2025            4  ...                   2
# 503         3            2025            1  ...                   2
# 504         4            2022            6  ...                   4
#
#      Internship  Scholarship  Placement_Status   Exam_Date  Total_Marks  \
# ...

# %%
print(st.tail(10))
# Out:
#     Student_ID Student_Name  Gender  Age        City      State Department  \
# 495       S496     Asha_496  Female   25    Belagavi  Karnataka       BCom
# 496       S497     Amit_497    Male   22     Dharwad  Karnataka        BSc
# 497       S498   Nikhil_498  Female   20  Shivamogga  Karnataka        MBA
# 498       S499    Manoj_499  Female   19     Dharwad  Karnataka       BCom
# 499       S500     Amit_500    Male   19   Bengaluru  Karnataka        MCA
# 500       S011     Rahul_11    Male   23      Mysuru  Karnataka        MBA
# 501       S087     Rohan_87  Female   18   Bengaluru  Karnataka        MCA
# 502       S154   Vikram_154  Female   19   Mangaluru  Karnataka       BCom
# 503       S259     Neha_259  Female   18    Hubballi  Karnataka        BCA
# 504       S332    Deepa_332    Male   19     Dharwad  Karnataka        MBA
#
#      Semester  Admission_Year  Study_Hours  ...  Projects_Completed  \
# 495         1            2023            6  ...                   4
# ...

# %%
st.sample()
# Out:
#     Student_ID Student_Name  Gender  Age      City      State Department  \
# 423       S424   Suresh_424  Female   23  Hubballi  Karnataka        BCA
#
#      Semester  Admission_Year  Study_Hours  ...  Projects_Completed  \
# 423         4            2022            7  ...                   4
#
#      Internship  Scholarship  Placement_Status   Exam_Date  Total_Marks  \
# 423          No          Yes        Not Placed  22-04-2025         88.7
#
#     Percentage Grade Pass_Status Remarks
# 423       88.7     A        Pass    Good
#
# [1 rows x 25 columns]

# %%
st.sample(10)
# Out:
#     Student_ID Student_Name  Gender  Age        City      State Department  \
# 213       S214    Kiran_214  Female   21      Mysuru  Karnataka        BCA
# 250       S251    Deepa_251    Male   20    Belagavi  Karnataka        BSc
# 445       S446    Pooja_446    Male   24     Dharwad  Karnataka        MCA
# 50        S051     Meena_51    Male   21    Hubballi  Karnataka        BCA
# 94        S095     Arjun_95    Male   22    Belagavi  Karnataka        BSc
# 413       S414    Kiran_414  Female   23     Dharwad  Karnataka        BCA
# 190       S191    Rohan_191  Female   25   Mangaluru  Karnataka        MCA
# 93        S094     Sneha_94  Female   25  Shivamogga  Karnataka        BCA
# 29        S030      Asha_30  Female   18    Hubballi  Karnataka        MCA
# 151       S152   Vikram_152    Male   24  Shivamogga  Karnataka        BCA
#
#      Semester  Admission_Year  Study_Hours  ...  Projects_Completed  \
# 213         4            2023            8  ...                   5
# ...

# %%
type(st)
# Out:
# pandas.core.frame.DataFrame

# %%
st["Gender"]
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3      Female
# 4      Female
#         ...
# 500      Male
# 501    Female
# 502    Female
# 503    Female
# 504      Male
# Name: Gender, Length: 505, dtype: object

# %%
st["Admission_Year"]
# Out:
# 0      2023
# 1      2023
# 2      2024
# 3      2022
# 4      2025
#        ...
# 500    2024
# 501    2025
# 502    2025
# 503    2025
# 504    2022
# Name: Admission_Year, Length: 505, dtype: int64

# %%
type(st["Admission_Year"])
# Out:
# pandas.core.series.Series

# %%
df=pd.DataFrame(st)
df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
st.shape
# Out:
# (505, 25)

# %%
len(st)
# Out:
# 505

# %%
len(st.columns)
# Out:
# 25

# %%
st.columns
# Out:
# Index(['Student_ID', 'Student_Name', 'Gender', 'Age', 'City', 'State',
#        'Department', 'Semester', 'Admission_Year', 'Study_Hours', 'Attendance',
#        'Assignment_Score', 'Quiz_Score', 'Internal_Marks', 'Final_Exam_Marks',
#        'Projects_Completed', 'Internship', 'Scholarship', 'Placement_Status',
#        'Exam_Date', 'Total_Marks', 'Percentage', 'Grade', 'Pass_Status',
#        'Remarks'],
#       dtype='object')

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_ID          505 non-null    object
#  1   Student_Name        504 non-null    object
#  2   Gender              505 non-null    object
#  3   Age                 505 non-null    int64
#  4   City                505 non-null    object
#  5   State               505 non-null    object
#  6   Department          504 non-null    object
#  7   Semester            505 non-null    int64
#  8   Admission_Year      505 non-null    int64
#  9   Study_Hours         505 non-null    int64
#  10  Attendance          504 non-null    float64
#  11  Assignment_Score    505 non-null    int64
#  12  Quiz_Score          505 non-null    int64
#  13  Internal_Marks      505 non-null    int64
#  14  Final_Exam_Marks    504 non-null    float64
# ...

# %%
st.dtypes
# Out:
# Student_ID             object
# Student_Name           object
# Gender                 object
# Age                     int64
# City                   object
# State                  object
# Department             object
# Semester                int64
# Admission_Year          int64
# Study_Hours             int64
# Attendance            float64
# Assignment_Score        int64
# Quiz_Score              int64
# Internal_Marks          int64
# Final_Exam_Marks      float64
# Projects_Completed      int64
# Internship             object
# Scholarship            object
# Placement_Status       object
# Exam_Date              object
# Total_Marks           float64
# Percentage            float64
# Grade                  object
# Pass_Status            object
# Remarks                object
# dtype: object

# %%
st.describe()
# Out:
#               Age    Semester  Admission_Year  Study_Hours  Attendance  \
# count  505.000000  505.000000      505.000000   505.000000  504.000000
# mean    21.396040    2.508911     2023.534653     5.461386   76.650794
# std      2.277736    1.160024        1.081632     2.924139   13.268488
# min     18.000000    1.000000     2022.000000     1.000000   55.000000
# 25%     19.000000    1.000000     2023.000000     3.000000   65.000000
# 50%     21.000000    3.000000     2024.000000     6.000000   77.000000
# 75%     23.000000    4.000000     2024.000000     8.000000   88.000000
# max     25.000000    4.000000     2025.000000    10.000000  100.000000
#
#        Assignment_Score  Quiz_Score  Internal_Marks  Final_Exam_Marks  \
# count        505.000000  505.000000      505.000000        504.000000
# mean          69.322772   69.639604       66.063366         65.289683
# std           17.954881   17.412731       20.680582         19.723219
# ...

# %%
st.describe(include='all')
# Out:
#        Student_ID Student_Name Gender         Age       City      State  \
# count         505          504    505  505.000000        505        505
# unique        500          499      2         NaN          7          1
# top          S332    Deepa_332   Male         NaN  Bengaluru  Karnataka
# freq            2            2    260         NaN         81        505
# mean          NaN          NaN    NaN   21.396040        NaN        NaN
# std           NaN          NaN    NaN    2.277736        NaN        NaN
# min           NaN          NaN    NaN   18.000000        NaN        NaN
# 25%           NaN          NaN    NaN   19.000000        NaN        NaN
# 50%           NaN          NaN    NaN   21.000000        NaN        NaN
# 75%           NaN          NaN    NaN   23.000000        NaN        NaN
# max           NaN          NaN    NaN   25.000000        NaN        NaN
#
#        Department    Semester  Admission_Year  Study_Hours  ...  \
# ...

# %%
st.index
# Out:
# RangeIndex(start=0, stop=505, step=1)

# %%
st.count()
# Out:
# Student_ID            505
# Student_Name          504
# Gender                505
# Age                   505
# City                  505
# State                 505
# Department            504
# Semester              505
# Admission_Year        505
# Study_Hours           505
# Attendance            504
# Assignment_Score      505
# Quiz_Score            505
# Internal_Marks        505
# Final_Exam_Marks      504
# Projects_Completed    505
# Internship            505
# Scholarship           505
# Placement_Status      505
# Exam_Date             504
# Total_Marks           505
# Percentage            505
# Grade                 505
# Pass_Status           505
# Remarks               505
# dtype: int64

# %%
st.isnull()
# Out:
#      Student_ID  Student_Name  Gender    Age   City  State  Department  \
# 0         False         False   False  False  False  False       False
# 1         False         False   False  False  False  False       False
# 2         False         False   False  False  False  False       False
# 3         False         False   False  False  False  False       False
# 4         False         False   False  False  False  False       False
# ..          ...           ...     ...    ...    ...    ...         ...
# 500       False         False   False  False  False  False       False
# 501       False         False   False  False  False  False       False
# 502       False         False   False  False  False  False       False
# 503       False         False   False  False  False  False       False
# 504       False         False   False  False  False  False       False
#
#      Semester  Admission_Year  Study_Hours  ...  Projects_Completed  \
# ...

# %%
st.isnull().sum()
# Out:
# Student_ID            0
# Student_Name          1
# Gender                0
# Age                   0
# City                  0
# State                 0
# Department            1
# Semester              0
# Admission_Year        0
# Study_Hours           0
# Attendance            1
# Assignment_Score      0
# Quiz_Score            0
# Internal_Marks        0
# Final_Exam_Marks      1
# Projects_Completed    0
# Internship            0
# Scholarship           0
# Placement_Status      0
# Exam_Date             1
# Total_Marks           0
# Percentage            0
# Grade                 0
# Pass_Status           0
# Remarks               0
# dtype: int64

# %%
st.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 500     True
# 501     True
# 502     True
# 503     True
# 504     True
# Length: 505, dtype: bool

# %%
st.duplicated().sum()
# Out:
# np.int64(5)

# %%
st.duplicated().unique ()
# Out:
# array([False,  True])

# %%
st["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
st["Admission_Year"].unique()
# Out:
# array([2023, 2024, 2022, 2025])

# %%
st["Gender"].value_counts()
# Out:
# Gender
# Male      260
# Female    245
# Name: count, dtype: int64

# %%
st["Department"].value_counts()
# Out:
# Department
# BCom    114
# MBA     103
# BSc      98
# BCA      96
# MCA      93
# Name: count, dtype: int64

# %%
st.memory_usage()
# Out:
# Index                  132
# Student_ID            4040
# Student_Name          4040
# Gender                4040
# Age                   4040
# City                  4040
# State                 4040
# Department            4040
# Semester              4040
# Admission_Year        4040
# Study_Hours           4040
# Attendance            4040
# Assignment_Score      4040
# Quiz_Score            4040
# Internal_Marks        4040
# Final_Exam_Marks      4040
# Projects_Completed    4040
# Internship            4040
# Scholarship           4040
# Placement_Status      4040
# Exam_Date             4040
# Total_Marks           4040
# Percentage            4040
# Grade                 4040
# Pass_Status           4040
# Remarks               4040
# dtype: int64

# %%
# data cleaning
# clean_data is already defined from cell cIXvTH6vSA7V

# %%
clean_data.isnull()
# Out:
#      Student_ID  Student_Name  Gender    Age   City  State  Department  \
# 0         False         False   False  False  False  False       False
# 1         False         False   False  False  False  False       False
# 2         False         False   False  False  False  False       False
# 3         False         False   False  False  False  False       False
# 4         False         False   False  False  False  False       False
# ..          ...           ...     ...    ...    ...    ...         ...
# 500       False         False   False  False  False  False       False
# 501       False         False   False  False  False  False       False
# 502       False         False   False  False  False  False       False
# 503       False         False   False  False  False  False       False
# 504       False         False   False  False  False  False       False
#
#      Semester  Admission_Year  Study_Hours  ...  Projects_Completed  \
# ...

# %%
clean_data.isnull().sum()
# Out:
# Student_ID            0
# Student_Name          1
# Gender                0
# Age                   0
# City                  0
# State                 0
# Department            1
# Semester              0
# Admission_Year        0
# Study_Hours           0
# Attendance            1
# Assignment_Score      0
# Quiz_Score            0
# Internal_Marks        0
# Final_Exam_Marks      1
# Projects_Completed    0
# Internship            0
# Scholarship           0
# Placement_Status      0
# Exam_Date             1
# Total_Marks           0
# Percentage            0
# Grade                 0
# Pass_Status           0
# Remarks               0
# dtype: int64

# %%
st.copy()
# Out:
#     Student_ID Student_Name  Gender  Age       City      State Department  \
# 0         S001      Anita_1    Male   19   Belagavi  Karnataka        MBA
# 1         S002     Suresh_2    Male   24  Bengaluru  Karnataka        BCA
# 2         S003     Suresh_3    Male   21   Hubballi  Karnataka        MBA
# 3         S004       Asha_4  Female   25   Belagavi  Karnataka        MBA
# 4         S005      Deepa_5  Female   25  Bengaluru  Karnataka        MCA
# ..         ...          ...     ...  ...        ...        ...        ...
# 500       S011     Rahul_11    Male   23     Mysuru  Karnataka        MBA
# 501       S087     Rohan_87  Female   18  Bengaluru  Karnataka        MCA
# 502       S154   Vikram_154  Female   19  Mangaluru  Karnataka       BCom
# 503       S259     Neha_259  Female   18   Hubballi  Karnataka        BCA
# 504       S332    Deepa_332    Male   19    Dharwad  Karnataka        MBA
#
#      Semester  Admission_Year  Study_Hours  ...  Projects_Completed  \
# ...

# %%
clean_data.isnull().sum().sum()
# Out:
# np.int64(5)

# %%
st=clean_data.dropna()
st
# Out:
#     Student_ID Student_Name  Gender  Age       City      State Department  \
# 0         S001      Anita_1    Male   19   Belagavi  Karnataka        MBA
# 1         S002     Suresh_2    Male   24  Bengaluru  Karnataka        BCA
# 2         S003     Suresh_3    Male   21   Hubballi  Karnataka        MBA
# 3         S004       Asha_4  Female   25   Belagavi  Karnataka        MBA
# 4         S005      Deepa_5  Female   25  Bengaluru  Karnataka        MCA
# ..         ...          ...     ...  ...        ...        ...        ...
# 500       S011     Rahul_11    Male   23     Mysuru  Karnataka        MBA
# 501       S087     Rohan_87  Female   18  Bengaluru  Karnataka        MCA
# 502       S154   Vikram_154  Female   19  Mangaluru  Karnataka       BCom
# 503       S259     Neha_259  Female   18   Hubballi  Karnataka        BCA
# 504       S332    Deepa_332    Male   19    Dharwad  Karnataka        MBA
#
#      Semester  Admission_Year  Study_Hours  ...  Projects_Completed  \
# ...

# %%
clean_data[clean_data.isnull().any(axis=1)]
# Out:
#     Student_ID Student_Name  Gender  Age        City      State Department  \
# 23        S024      Ravi_24  Female   25     Dharwad  Karnataka        BCA
# 75        S076          NaN    Male   20   Bengaluru  Karnataka        BCA
# 121       S122     Neha_122    Male   25   Mangaluru  Karnataka        NaN
# 248       S249   Vikram_249  Female   21   Bengaluru  Karnataka       BCom
# 399       S400     Asha_400    Male   20  Shivamogga  Karnataka        MBA
#
#      Semester  Admission_Year  Study_Hours  ...  Projects_Completed  \
# 23          3            2024            1  ...                   0
# 75          3            2024            6  ...                   2
# 121         2            2022            7  ...                   3
# 248         2            2022            4  ...                   5
# 399         4            2023            9  ...                   2
#
#      Internship  Scholarship  Placement_Status   Exam_Date  Total_Marks  \
# ...

# %%
clean_data["Attendance"]=clean_data["Attendance"].fillna(clean_data["Attendance"].median())

# %%
clean_data["Gender"]=clean_data["Gender"].fillna(clean_data["Gender"].mode()[0])

# %%
clean_data["Study_Hours"]=clean_data["Study_Hours"].fillna(clean_data["Study_Hours"].mean())

# %%
clean_data.duplicated().sum()
# Out:
# np.int64(5)

# %%
clean_data[clean_data.duplicated()]
# Out:
#     Student_ID Student_Name  Gender  Age       City      State Department  \
# 500       S011     Rahul_11    Male   23     Mysuru  Karnataka        MBA
# 501       S087     Rohan_87  Female   18  Bengaluru  Karnataka        MCA
# 502       S154   Vikram_154  Female   19  Mangaluru  Karnataka       BCom
# 503       S259     Neha_259  Female   18   Hubballi  Karnataka        BCA
# 504       S332    Deepa_332    Male   19    Dharwad  Karnataka        MBA
#
#      Semester  Admission_Year  Study_Hours  ...  Projects_Completed  \
# 500         1            2024            2  ...                   2
# 501         4            2025            6  ...                   2
# 502         4            2025            4  ...                   2
# 503         3            2025            1  ...                   2
# 504         4            2022            6  ...                   4
#
#      Internship  Scholarship  Placement_Status   Exam_Date  Total_Marks  \
# ...

# %%
clean_data=clean_data.drop_duplicates()
clean_data
# Out:
#     Student_ID Student_Name  Gender  Age        City      State Department  \
# 0         S001      Anita_1    Male   19    Belagavi  Karnataka        MBA
# 1         S002     Suresh_2    Male   24   Bengaluru  Karnataka        BCA
# 2         S003     Suresh_3    Male   21    Hubballi  Karnataka        MBA
# 3         S004       Asha_4  Female   25    Belagavi  Karnataka        MBA
# 4         S005      Deepa_5  Female   25   Bengaluru  Karnataka        MCA
# ..         ...          ...     ...  ...         ...        ...        ...
# 495       S496     Asha_496  Female   25    Belagavi  Karnataka       BCom
# 496       S497     Amit_497    Male   22     Dharwad  Karnataka        BSc
# 497       S498   Nikhil_498  Female   20  Shivamogga  Karnataka        MBA
# 498       S499    Manoj_499  Female   19     Dharwad  Karnataka       BCom
# 499       S500     Amit_500    Male   19   Bengaluru  Karnataka        MCA
#
# ...

# %%
lean_data[clean_data.duplicated()]
# Out:
# /tmp/ipykernel_1998/435938518.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data["Age"]=clean_data["Age"].astype(int)

# %%
clean_data["final_Exam_Marks"]=clean_data["Final_Exam_Marks"].astype(float)
# Out:
# /tmp/ipykernel_1998/2535020100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data["final_Exam_Marks"]=clean_data["Final_Exam_Marks"].astype(float)

# %%
clean_data["Gender"]=clean_data["Gender"].str.strip().str.title()
# Out:
# /tmp/ipykernel_1998/3446277443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data["Gender"]=clean_data["Gender"].str.strip().str.title()

# %%
clean_data[clean_data["Attendance"]<0]
# Out:
# Empty DataFrame
# Columns: [Student_ID, Student_Name, Gender, Age, City, State, Department, Semester, Admission_Year, Study_Hours, Attendance, Assignment_Score, Quiz_Score, Internal_Marks, Final_Exam_Marks, Projects_Completed, Internship, Scholarship, Placement_Status, Exam_Date, Total_Marks, Percentage, Grade, Pass_Status, Remarks, final_Exam_Marks]
# Index: []
#
# [0 rows x 26 columns]

# %%
# transform date
st.columns = st.columns.str.replace("_", " ")
st
# Out:
#     Student ID Student Name  Gender  Age       City      State Department  \
# 0         S001      Anita_1    Male   19   Belagavi  Karnataka        MBA
# 1         S002     Suresh_2    Male   24  Bengaluru  Karnataka        BCA
# 2         S003     Suresh_3    Male   21   Hubballi  Karnataka        MBA
# 3         S004       Asha_4  Female   25   Belagavi  Karnataka        MBA
# 4         S005      Deepa_5  Female   25  Bengaluru  Karnataka        MCA
# ..         ...          ...     ...  ...        ...        ...        ...
# 500       S011     Rahul_11    Male   23     Mysuru  Karnataka        MBA
# 501       S087     Rohan_87  Female   18  Bengaluru  Karnataka        MCA
# 502       S154   Vikram_154  Female   19  Mangaluru  Karnataka       BCom
# 503       S259     Neha_259  Female   18   Hubballi  Karnataka        BCA
# 504       S332    Deepa_332    Male   19    Dharwad  Karnataka        MBA
#
#      Semester  Admission Year  Study Hours  ...  Projects Completed  \
# ...

# %%
st.columns = st.columns.str.replace("_","")
st
# Out:
#     StudentID StudentName  Gender  Age       City      State Department  \
# 0        S001     Anita_1    Male   19   Belagavi  Karnataka        MBA
# 1        S002    Suresh_2    Male   24  Bengaluru  Karnataka        BCA
# 2        S003    Suresh_3    Male   21   Hubballi  Karnataka        MBA
# 3        S004      Asha_4  Female   25   Belagavi  Karnataka        MBA
# 4        S005     Deepa_5  Female   25  Bengaluru  Karnataka        MCA
# ..        ...         ...     ...  ...        ...        ...        ...
# 500      S011    Rahul_11    Male   23     Mysuru  Karnataka        MBA
# 501      S087    Rohan_87  Female   18  Bengaluru  Karnataka        MCA
# 502      S154  Vikram_154  Female   19  Mangaluru  Karnataka       BCom
# 503      S259    Neha_259  Female   18   Hubballi  Karnataka        BCA
# 504      S332   Deepa_332    Male   19    Dharwad  Karnataka        MBA
#
#      Semester  AdmissionYear  StudyHours  ...  ProjectsCompleted  Internship  \
# ...

# %%
st["Age"] = st["Age"] .astype(int)
st
# Out:
# /tmp/ipykernel_1998/2135598648.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st["Age"] = st["Age"] .astype(int)
#     StudentID StudentName  Gender  Age       City      State Department  \
# 0        S001     Anita_1    Male   19   Belagavi  Karnataka        MBA
# 1        S002    Suresh_2    Male   24  Bengaluru  Karnataka        BCA
# 2        S003    Suresh_3    Male   21   Hubballi  Karnataka        MBA
# 3        S004      Asha_4  Female   25   Belagavi  Karnataka        MBA
# 4        S005     Deepa_5  Female   25  Bengaluru  Karnataka        MCA
# ..        ...         ...     ...  ...        ...        ...        ...
# 500      S011    Rahul_11    Male   23     Mysuru  Karnataka        MBA
# ...

# %%
st["Percentage"] = st["Percentage"] .astype(float)
st
# Out:
# /tmp/ipykernel_1998/3676841495.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st["Percentage"] = st["Percentage"] .astype(float)
#     StudentID StudentName  Gender  Age       City      State Department  \
# 0        S001     Anita_1    Male   19   Belagavi  Karnataka        MBA
# 1        S002    Suresh_2    Male   24  Bengaluru  Karnataka        BCA
# 2        S003    Suresh_3    Male   21   Hubballi  Karnataka        MBA
# 3        S004      Asha_4  Female   25   Belagavi  Karnataka        MBA
# 4        S005     Deepa_5  Female   25  Bengaluru  Karnataka        MCA
# ..        ...         ...     ...  ...        ...        ...        ...
# 500      S011    Rahul_11    Male   23     Mysuru  Karnataka        MBA
# ...

# %%
st["Total_marks"] = st["AssignmentScore"] + st["QuizScore"] + st["InternalMarks"]
st
# Out:
# /tmp/ipykernel_1998/246217172.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st["Total_marks"] = st["AssignmentScore"] + st["QuizScore"] + st["InternalMarks"]
#     StudentID StudentName  Gender  Age       City      State Department  \
# 0        S001     Anita_1    Male   19   Belagavi  Karnataka        MBA
# 1        S002    Suresh_2    Male   24  Bengaluru  Karnataka        BCA
# 2        S003    Suresh_3    Male   21   Hubballi  Karnataka        MBA
# 3        S004      Asha_4  Female   25   Belagavi  Karnataka        MBA
# 4        S005     Deepa_5  Female   25  Bengaluru  Karnataka        MCA
# ..        ...         ...     ...  ...        ...        ...        ...
# ...

# %%
st["Total percentage"]=(st["Total_marks"]/100)*100
st
# Out:
# /tmp/ipykernel_1998/3152500588.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st["Total percentage"]=(st["Total_marks"]/100)*100
#     StudentID StudentName  Gender  Age       City      State Department  \
# 0        S001     Anita_1    Male   19   Belagavi  Karnataka        MBA
# 1        S002    Suresh_2    Male   24  Bengaluru  Karnataka        BCA
# 2        S003    Suresh_3    Male   21   Hubballi  Karnataka        MBA
# 3        S004      Asha_4  Female   25   Belagavi  Karnataka        MBA
# 4        S005     Deepa_5  Female   25  Bengaluru  Karnataka        MCA
# ..        ...         ...     ...  ...        ...        ...        ...
# 500      S011    Rahul_11    Male   23     Mysuru  Karnataka        MBA
# ...

# %%
def garde(Marks) :
  if Marks >= 90 :
    return "A"
  elif Marks >= 80 :
    return "B"
  elif Marks >= 70 :
    return "C"
  elif Marks >= 60 :
    return "D"
  else :
    return "F"
  clean_data["grade"]=clean_data["Percentage"].apply(grade)

# %%
st.sort_values("StudyHours")
st
# Out:
#     StudentID StudentName  Gender  Age       City      State Department  \
# 0        S001     Anita_1    Male   19   Belagavi  Karnataka        MBA
# 1        S002    Suresh_2    Male   24  Bengaluru  Karnataka        BCA
# 2        S003    Suresh_3    Male   21   Hubballi  Karnataka        MBA
# 3        S004      Asha_4  Female   25   Belagavi  Karnataka        MBA
# 4        S005     Deepa_5  Female   25  Bengaluru  Karnataka        MCA
# ..        ...         ...     ...  ...        ...        ...        ...
# 500      S011    Rahul_11    Male   23     Mysuru  Karnataka        MBA
# 501      S087    Rohan_87  Female   18  Bengaluru  Karnataka        MCA
# 502      S154  Vikram_154  Female   19  Mangaluru  Karnataka       BCom
# 503      S259    Neha_259  Female   18   Hubballi  Karnataka        BCA
# 504      S332   Deepa_332    Male   19    Dharwad  Karnataka        MBA
#
#      Semester  AdmissionYear  StudyHours  ...  Scholarship  PlacementStatus  \
# ...

# %%
clean_data.sort_values("Study_Hours",ascending=False)
# Out:
#     Student_ID Student_Name  Gender  Age        City      State Department  \
# 277       S278    Manoj_278  Female   21   Bengaluru  Karnataka        BSc
# 288       S289    Kavya_289    Male   21      Mysuru  Karnataka        BCA
# 44        S045    Nikhil_45    Male   22  Shivamogga  Karnataka        BSc
# 264       S265    Rohan_265  Female   19    Hubballi  Karnataka        MBA
# 265       S266    Deepa_266    Male   22  Shivamogga  Karnataka        MBA
# ..         ...          ...     ...  ...         ...        ...        ...
# 42        S043     Arjun_43  Female   21    Hubballi  Karnataka        MBA
# 23        S024      Ravi_24  Female   25     Dharwad  Karnataka        BCA
# 470       S471    Meena_471  Female   20  Shivamogga  Karnataka        BSc
# 475       S476    Deepa_476    Male   22    Hubballi  Karnataka       BCom
# 0         S001      Anita_1    Male   19    Belagavi  Karnataka        MBA
#
# ...

# %%
clean_data[clean_data["Department"]=='BCA']
# Out:
#     Student_ID Student_Name  Gender  Age       City      State Department  \
# 1         S002     Suresh_2    Male   24  Bengaluru  Karnataka        BCA
# 5         S006      Pooja_6    Male   25  Bengaluru  Karnataka        BCA
# 12        S013      Neha_13  Female   21   Belagavi  Karnataka        BCA
# 20        S021     Manoj_21  Female   19  Bengaluru  Karnataka        BCA
# 23        S024      Ravi_24  Female   25    Dharwad  Karnataka        BCA
# ..         ...          ...     ...  ...        ...        ...        ...
# 483       S484    Kiran_484  Female   19   Hubballi  Karnataka        BCA
# 486       S487    Kavya_487    Male   25   Belagavi  Karnataka        BCA
# 489       S490    Divya_490    Male   18     Mysuru  Karnataka        BCA
# 492       S493    Divya_493    Male   18  Bengaluru  Karnataka        BCA
# 493       S494    Deepa_494    Male   24   Hubballi  Karnataka        BCA
#
#      Semester  Admission_Year  Study_Hours  ...  Internship  Scholarship  \
# ...

# %%
clean_data[clean_data["Department"]=='Bengaluru']
# Out:
# Empty DataFrame
# Columns: [Student_ID, Student_Name, Gender, Age, City, State, Department, Semester, Admission_Year, Study_Hours, Attendance, Assignment_Score, Quiz_Score, Internal_Marks, Final_Exam_Marks, Projects_Completed, Internship, Scholarship, Placement_Status, Exam_Date, Total_Marks, Percentage, Grade, Pass_Status, Remarks, final_Exam_Marks]
# Index: []
#
# [0 rows x 26 columns]

# %%
clean_data[clean_data["Exam_Date"] > "06-07-2025"]
# Out:
#     Student_ID Student_Name  Gender  Age       City      State Department  \
# 2         S003     Suresh_3    Male   21   Hubballi  Karnataka        MBA
# 3         S004       Asha_4  Female   25   Belagavi  Karnataka        MBA
# 4         S005      Deepa_5  Female   25  Bengaluru  Karnataka        MCA
# 5         S006      Pooja_6    Male   25  Bengaluru  Karnataka        BCA
# 6         S007      Arjun_7  Female   23  Mangaluru  Karnataka       BCom
# ..         ...          ...     ...  ...        ...        ...        ...
# 493       S494    Deepa_494    Male   24   Hubballi  Karnataka        BCA
# 494       S495   Nikhil_495    Male   25     Mysuru  Karnataka       BCom
# 496       S497     Amit_497    Male   22    Dharwad  Karnataka        BSc
# 498       S499    Manoj_499  Female   19    Dharwad  Karnataka       BCom
# 499       S500     Amit_500    Male   19  Bengaluru  Karnataka        MCA
#
#      Semester  Admission_Year  Study_Hours  ...  Internship  Scholarship  \
# ...

# %%
clean_data.groupby("Department")["Percentage"].sum()
# Out:
# Department
# BCA     6313.7
# BCom    7572.8
# BSc     6461.0
# MBA     6736.8
# MCA     6212.7
# Name: Percentage, dtype: float64

# %%
clean_data.groupby("Department")["Student_Name"].countm()
# Out:
# Department
# BCA      94
# BCom    113
# BSc      98
# MBA     101
# MCA      92
# Name: Student_Name, dtype: int64

# %%
clean_data.groupby("Gender")["Attendance"].mean()
# Out:
# Gender
# Female    76.078512
# Male      76.953488
# Name: Attendance, dtype: float64

# %%
clean_data.groupby("Department").agg({"Percentage":["mean","count","max","min"],"Attendance":"mean"})
# Out:
#            Percentage                   Attendance
#                  mean count   max   min       mean
# Department
# BCA         66.460000    95  88.7  40.8  77.957895
# BCom        67.015929   113  87.9  42.5  74.345133
# BSc         65.928571    98  88.1  41.5  77.295918
# MBA         66.700990   101  90.4  40.5  75.900990
# MCA         67.529348    92  93.8  39.2  77.369565

# %%
clean_data["rank"]=clean_data["Percentage"].rank(ascending=False)
clean_data
# Out:
#     Student_ID Student_Name  Gender  Age        City      State Department  \
# 0         S001      Anita_1    Male   19    Belagavi  Karnataka        MBA
# 1         S002     Suresh_2    Male   24   Bengaluru  Karnataka        BCA
# 2         S003     Suresh_3    Male   21    Hubballi  Karnataka        MBA
# 3         S004       Asha_4  Female   25    Belagavi  Karnataka        MBA
# 4         S005      Deepa_5  Female   25   Bengaluru  Karnataka        MCA
# ..         ...          ...     ...  ...         ...        ...        ...
# 495       S496     Asha_496  Female   25    Belagavi  Karnataka       BCom
# 496       S497     Amit_497    Male   22     Dharwad  Karnataka        BSc
# 497       S498   Nikhil_498  Female   20  Shivamogga  Karnataka        MBA
# 498       S499    Manoj_499  Female   19     Dharwad  Karnataka       BCom
# 499       S500     Amit_500    Male   19   Bengaluru  Karnataka        MCA
#
#      Semester  Admission_Year  Study_Hours  ...  Scholarship  \
# ...

# %%
 clean_data.head()
# Out:
#   Student_ID Student_Name  Gender  Age       City      State Department  \
# 0       S001      Anita_1    Male   19   Belagavi  Karnataka        MBA
# 1       S002     Suresh_2    Male   24  Bengaluru  Karnataka        BCA
# 2       S003     Suresh_3    Male   21   Hubballi  Karnataka        MBA
# 3       S004       Asha_4  Female   25   Belagavi  Karnataka        MBA
# 4       S005      Deepa_5  Female   25  Bengaluru  Karnataka        MCA
#
#    Semester  Admission_Year  Study_Hours  ...  Scholarship  Placement_Status  \
# 0         1            2023            1  ...          Yes            Placed
# 1         1            2023            5  ...           No            Placed
# 2         4            2024            8  ...           No            Placed
# 3         1            2022            9  ...          Yes        Not Placed
# 4         3            2025            2  ...           No        Not Placed
#
# ...

# %%
clean_data.shape[0]
# Out:
# 500

# %%
clean_data.shape[1]
# Out:
# 27

# %%
clean_data["Percentage"].mean()
# Out:
# np.float64(66.74380000000001)

# %%
clean_data["Grade"].mode()[0]
# Out:
# 'B'

# %%
#find top 10 student
clean_data.sort_values("Percentage",ascending=False).head(10)
# Out:
#     Student_ID Student_Name  Gender  Age        City      State Department  \
# 136       S137     Amit_137    Male   24     Dharwad  Karnataka        MCA
# 418       S419    Anita_419  Female   22    Belagavi  Karnataka        MBA
# 259       S260    Rohan_260    Male   22      Mysuru  Karnataka        MBA
# 467       S468     Asha_468    Male   23    Belagavi  Karnataka        MCA
# 423       S424   Suresh_424  Female   23    Hubballi  Karnataka        BCA
# 375       S376    Pooja_376  Female   19   Bengaluru  Karnataka        BSc
# 76        S077     Priya_77    Male   24   Bengaluru  Karnataka       BCom
# 429       S430     Neha_430    Male   22     Dharwad  Karnataka        BSc
# 347       S348    Arjun_348    Male   24  Shivamogga  Karnataka       BCom
# 322       S323     Neha_323  Female   22    Belagavi  Karnataka       BCom
#
#      Semester  Admission_Year  Study_Hours  ...  Scholarship  \
# 136         2            2023            9  ...          Yes
# ...

# %%
clean_data.sort_values("Percentage",ascending=False).tail(10)
# Out:
#     Student_ID Student_Name  Gender  Age        City      State Department  \
# 198       S199     Ravi_199  Female   25   Mangaluru  Karnataka       BCom
# 45        S046     Kavya_46    Male   18      Mysuru  Karnataka       BCom
# 268       S269    Meena_269    Male   22      Mysuru  Karnataka        BSc
# 99        S100    Kiran_100    Male   19      Mysuru  Karnataka       BCom
# 441       S442    Priya_442    Male   25   Bengaluru  Karnataka        MCA
# 157       S158    Manoj_158  Female   23   Bengaluru  Karnataka       BCom
# 267       S268    Kiran_268    Male   20    Hubballi  Karnataka        BSc
# 206       S207    Manoj_207    Male   24   Mangaluru  Karnataka        BCA
# 74        S075     Kiran_75    Male   19  Shivamogga  Karnataka        MBA
# 281       S282     Neha_282  Female   19     Dharwad  Karnataka        MCA
#
#      Semester  Admission_Year  Study_Hours  ...  Scholarship  \
# 198         2            2024            6  ...           No
# ...

# %%
clean_data.groupby("Department")["Percentage"].mean()
# Out:
# Department
# BCA     66.460000
# BCom    67.015929
# BSc     65.928571
# MBA     66.700990
# MCA     67.529348
# Name: Percentage, dtype: float64

# %%
clean_data["City"].value_counts()
# Out:
# City
# Bengaluru     80
# Shivamogga    75
# Mangaluru     73
# Mysuru        72
# Dharwad       70
# Belagavi      67
# Hubballi      63
# Name: count, dtype: int64

# %%
clean_data["Grade"].value_counts()
# Out:
# Grade
# B       170
# B+      152
# C       105
# A        45
# Fail     26
# A+        2
# Name: count, dtype: int64

# %%
data.groupby

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_excel("Data.xlsx")
clean_data = df.copy()


department = clean_data.groupby("Department")["Percentage"].mean()

Colors = ["blue", "red", "green", "pink", "black"]
plt.bar(department.index, department.values, color=Colors)
plt.xlabel("Department")
plt.ylabel("Averagewise Percentage")
plt.title("Department wise average Percentage")
plt.grid()
plt.show()

# %%
clean_data["Attendance"]
# Out:
# 0      60.0
# 1      81.0
# 2      92.0
# 3      81.0
# 4      58.0
#        ...
# 500    99.0
# 501    92.0
# 502    89.0
# 503    91.0
# 504    73.0
# Name: Attendance, Length: 505, dtype: float64

# %%
clean_data["Percentage"]
# Out:
# 0      70.7
# 1      57.0
# 2      61.5
# 3      77.3
# 4      74.7
#        ...
# 500    77.9
# 501    63.0
# 502    60.0
# 503    74.3
# 504    84.0
# Name: Percentage, Length: 505, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.plot(clean_data["Attendance"],label = "Attendance")
plt.plot(clean_data["Percentage"], label = "Percentage")

plt.title("Attendance Vs Percentage")
plt.xlabel("Student")
plt.ylabel("Attendance")
plt.legend()
plt.show()

# %%
clean_data["City"].unique()
# Out:
# array(['Belagavi', 'Bengaluru', 'Hubballi', 'Mangaluru', 'Mysuru',
#        'Dharwad', 'Shivamogga'], dtype=object)

# %%
import matplotlib.pyplot as plt

city = clean_data["City"].value_counts()
colors=["red","pink","green","black","yellow","orange","skyblue"]

plt.barh(city.index,city.values,color=colors,alpha=0.6)

plt.title("City wise student counts")

plt.xlabel("Student")
plt.ylabel("City")


plt.show()

# %%
clean_data["Grade"].value_counts()
# Out:
# Grade
# B       172
# B+      154
# C       105
# A        46
# Fail     26
# A+        2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

grade=clean_data["Grade"].value_counts()
colors=["red","pink","green","black","yellow"]

plt.bar(grade.index,grade.values,color=colors)

plt.title("Grade wise student counts")

plt.xlabel("Grade")
plt.ylabel("Student")

plt.show()

# %%
clean_data["Study_Hours"]
# Out:
# 0      1
# 1      5
# 2      8
# 3      9
# 4      2
#       ..
# 500    2
# 501    6
# 502    4
# 503    1
# 504    6
# Name: Study_Hours, Length: 505, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.scatter(clean_data["Study_Hours"],clean_data["Percentage"])

plt.title("Study Hours Vs Percentage")
plt.xlabel("Study Hours")
plt.ylabel("Percentage")

plt.show()

# %%
import matplotlib.pyplot as plt

gender = clean_data["Gender"].value_counts()

plt.pie(gender.values,labels = gender.index, startangle=90,autopct="%1.1f%%")

plt.title("Gender wise student counts")

plt.show()

# %%
# Student Percentage Trends

import matplotlib.pyplot as plt

plt.plot(clean_data["Percentage"],color = "Skyblue",alpha = 0.7)
plt.title("Student Percentage Trends")

plt.xlabel("Student")
plt.ylabel("Percentage")

plt.show()

# %%
# Study Hours Distributions
import matplotlib.pyplot as plt

plt.hist(clean_data["Study_Hours"],bins=10,color="pink",edgecolor="red",alpha=0.7)

plt.title("Study Hours Distributions")
plt.xlabel("Study Hours")
plt.ylabel("Frequency")

plt.show()
